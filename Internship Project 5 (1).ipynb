# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time
import requests
import re

# %%
driver=webdriver.Chrome(r'C:\\Users\\Harshit Reddy\\Downloads\\chromedriver_win32\\chromedriver.exe')

# %% [markdown]
# 1.Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
url='https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

# %%
rank=[]
try:
    Rank=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")  
    for i in Rank:
        rank.append(i.text)
except NoSuchElementException:  
        rank.append('No details available')
except NoSuchElementException:   
        rank.append('No details available')
        
name=[]
try:
    Names=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")  
    for i in Names:
        name.append(i.text)
except NoSuchElementException:  
        name.append('No details available')
except NoSuchElementException:   
        name.append('No details available')
        
artist=[]
try:
    Artist=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")  
    for i in Artist:
        artist.append(i.text)
except NoSuchElementException:  
        artist.append('No details available')
except NoSuchElementException:   
        artist.append('No details available')   
        
views=[]
try:
    Views=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")  
    for i in Views:
        views.append(i.text)
except NoSuchElementException:
        views.append('No details available')
except NoSuchElementException:   
        views.append('No details available') 
        
date=[]
try:
    Upload_Date=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")  
    for i in Upload_Date:
        date.append(i.text)
except NoSuchElementException: 
        date.append('No details available')
except NoSuchElementException:   
        date.append('No details available')

# %%
Wikipedia=pd.DataFrame()
Wikipedia['Rank']=rank
Wikipedia['Name']=name
Wikipedia['Artist']=artist
Wikipedia['Upload_Date']=date
Wikipedia['Views']=views
Wikipedia
# Out:
#    Rank                                             Name  \
# 0    1.                           "Baby Shark Dance"[22]
# 1    2.                                  "Despacito"[24]
# 2    3.                       "Johny Johny Yes Papa"[25]
# 3    4.                               "Shape of You"[26]
# 4    5.                              "See You Again"[27]
# 5    6.   "Masha and the Bear – Recipe for Disaster"[30]
# 6    7.                                  "Bath Song"[31]
# 7    8.  "Learning Colors – Colorful Eggs on a Farm"[32]
# 8    9.                                "Uptown Funk"[33]
# 9   10.                              "Gangnam Style"[34]
# 10  11.                "Phonics Song with Two Words"[36]
# 11  12.                                      "Sugar"[37]
# 12  13.                                      "Sorry"[38]
# 13  14.                             "Dame Tu Cosita"[39]
# 14  15.                                       "Roar"[40]
# ...

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time.
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
url="https://www.bcci.tv/"
driver.get(url)

# %%
show=driver.find_element_by_xpath('//a[@href="/international/fixtures"]')
show.click()

# %%
Match_Title=driver.find_elements_by_xpath('//strong[@class="fixture__name fixture__name--with-margin"]')
match_Title=[]
for i in Match_Title:
    match_Title.append(i.text)
Date=driver.find_elements_by_xpath('//span[@class="fixture__date"]')
date=[]
for i in Date:
    date.append(i.text)
Series=driver.find_elements_by_xpath('//div[@class="fixture__teams"]')
series=[]
for i in Series:
    series.append(i.text.replace('\n',' '))
Place=driver.find_elements_by_xpath('//p[@class="fixture__additional-info"]')
place=[]
for i in Place:
    place.append(i.text.replace('1st ODI\n',' '))
Time=driver.find_elements_by_xpath('//span[@class="fixture__time"]')
time=[]
for i in Time:
    time.append(i.text)

# %%
Matches=pd.DataFrame()
Matches['Match_Title']=match_Title[0:11]
Matches['Series']=series[0:11]
Matches['Place']=place[0:11]
Matches['Date']=date[0:11]
Matches['Time']=time[0:11]
Matches
# Out:
#    Match_Title             Series                                   Place  \
# 0      1st ODI  SRI LANKA v INDIA   1st ODI\nR Premadasa Stadium, Colombo
# 1      2nd ODI  SRI LANKA v INDIA   2nd ODI\nR Premadasa Stadium, Colombo
# 2      3rd ODI  SRI LANKA v INDIA   3rd ODI\nR Premadasa Stadium, Colombo
# 3     1st T20I  SRI LANKA v INDIA  1st T20I\nR Premadasa Stadium, Colombo
# 4     2nd T20I  SRI LANKA v INDIA  2nd T20I\nR Premadasa Stadium, Colombo
# 5     3rd T20I  SRI LANKA v INDIA  3rd T20I\nR Premadasa Stadium, Colombo
# 6     1st Test    ENGLAND v INDIA      1st Test\nTrent Bridge, Nottingham
# 7     2nd Test    ENGLAND v INDIA                2nd Test\nLord's, London
# 8     3rd Test    ENGLAND v INDIA             3rd Test\nHeadingley, Leeds
# 9     4th Test    ENGLAND v INDIA              4th Test\nThe Oval, London
# 10    5th Test    ENGLAND v INDIA      5th Test\nOld Trafford, Manchester
#
#    Date       Time
# 0    13  14:30 IST
# 1    16  14:30 IST
# ...

# %% [markdown]
# 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
url='https://www.guru99.com/'
driver.get(url)

# %%
selenium_link=driver.find_element_by_xpath("//li[@class='g-menu-item g-menu-item-type-component g-menu-item-121  ']/a")
try:
    selenium_link.click()
except ElementNotInteractableException:         
    driver.get(selenium_link.get_attribute('href'))
time.sleep(2)

exception_handle_link=driver.find_element_by_xpath("//a[@title='Selenium Exception Handling (Common Exceptions List)']")
try:
    exception_handle_link.click()
except ElementNotInteractableException:      
    driver.get(exception_handle_link.get_attribute('href'))

# %%
name=[]
try:
    Name=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[1]")
    for i in Name:
        name.append(i.text)
except NoSuchElementException:
    name.append('No details available')

desc=[]
try:
    Description=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[2]")
    for i in Description:
        desc.append(i.text)
except NoSuchElementException:
    desc.append('No details available')

# %%
Exception=pd.DataFrame()
Exception['Name']=name[1:]
Exception['Description']=desc[1:]
Exception
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP at current price (19-20)
# D) GSDP at current price (18-19)
# E) Share(18-19)
# F) GDP($ billion).
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
url='http://statisticstimes.com/'
driver.get(url)

# %%
economy=driver.find_element_by_xpath("//div[@class='dropdown'][2]/div/a[3]")
try:
    economy.click()
except ElementNotInteractableException:
    driver.get(economy.get_attribute('href'))
time.sleep(2)

# %%
indian_states=driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']//li[1]/a")
try:
    indian_states.click()
except ElementNotInteractableException:
    driver.get(indian_states.get_attribute('href')) 
time.sleep(2)

# %%
rank=[]
try:
    Rank=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[1]")
    for i in Rank:
        rank.append(i.text)
except NoSuchElementException:
    rank.append('No details available')

state=[]
try:
    State=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[2]")
    for i in State:
        state.append(i.text)
except NoSuchElementException:
    state.append('No details available')    
    
GSDP=[]
try:
    GSDP_at_Current_Price_19_20=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[3]")
    for i in GSDP_at_Current_Price_19_20:
        GSDP.append(i.text)
except NoSuchElementException:
    GSDP.append('No details available')    
    
gsdp=[]
try:
    GSDP_at_Current_Price_18_19=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[4]")
    for i in GSDP_at_Current_Price_18_19:
        gsdp.append(i.text)
except NoSuchElementException:
    gsdp.append('No details available')    
    
share=[]
try:
    Share_18_19=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[5]")
    for i in Share_18_19:
        share.append(i.text)
except NoSuchElementException:
    share.append('No details available')    
        
gdp=[]
try:
    GDP_Dollar_Billion=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[6]")
    for i in GDP_Dollar_Billion:
        gdp.append(i.text)
except NoSuchElementException:
    gdp.append('No details available')

# %%
GDP=pd.DataFrame()
GDP['Rank']=rank
GDP['State']=state
GDP['GSDP_at_Current_Price_19_20']=GSDP
GDP['GSDP_at_Current_Price_18_19']=gsdp
GDP['Share_18_19']=share
GDP['GDP_Dollar_Billion']=gdp
GDP
# Out:
#    Rank                      State GSDP_at_Current_Price_19_20  \
# 0     1                Maharashtra                           -
# 1     2                 Tamil Nadu                   1,845,853
# 2     3              Uttar Pradesh                   1,687,818
# 3     4                    Gujarat                           -
# 4     5                  Karnataka                   1,631,977
# 5     6                West Bengal                   1,253,832
# 6     7                  Rajasthan                   1,020,989
# 7     8             Andhra Pradesh                     972,782
# 8     9                  Telangana                     969,604
# 9    10             Madhya Pradesh                     906,672
# 10   11                     Kerala                           -
# 11   12                      Delhi                     856,112
# 12   13                    Haryana                     831,610
# 13   14                      Bihar                     611,804
# ...

# %% [markdown]
# 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
url="https://github.com/"
driver.get(url)

# %%
Repository_Title=driver.find_elements_by_xpath('//span[@class="text-normal"]')
title=[]
for i in Repository_Title:
    title.append(i.text.replace('/',' '))
    
Repository_Description=driver.find_elements_by_xpath('//p[@class="col-9 color-text-secondary my-1 pr-4"]')
desc=[]
for i in Repository_Description:
    desc.append(i.text)
    
Language=driver.find_elements_by_xpath('//span[@class="d-inline-block ml-0 mr-3"]')
language=[]
for i in Language:
    language.append(i.text)

# %%
Github=pd.DataFrame()
Github['Repository_Title']=title[0:19]
Github['Repository_Description']=desc[0:19]
Github['Language']=language[0:19]
Github
# Out:
#      Repository_Title                             Repository_Description  \
# 0          ailabstw               Taiwan Social Distancing App - Android
# 1          ailabstw                   Taiwan Social Distancing App - iOS
# 2        shufflewzc                                              不知名大佬备份
# 3            airbnb                               JavaScript Style Guide
# 4             laynH                Anime Girls Holding Programming Books
# 5       swisskyrepo    A list of useful payloads and bypass for Web A...
# 6          trekhleb    📝 Algorithms and data structures implemented i...
# 7         go-kratos                    A Go framework for microservices.
# 8          iptv-org    Collection of publicly available IPTV channels...
# 9        30-seconds    Short JavaScript code snippets for all your de...
# 10  spring-projects                       Spring integration for GraphQL
# 11        microsoft                   12 Weeks, 24 Lessons, IoT for All!
# ...

# %% [markdown]
# 6. Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board

# %%
url="https://www.billboard.com/"
driver.get(url)

# %%
show=driver.find_element_by_xpath('//a[@href="/charts"]')
show.click()

# %%
show1=driver.find_element_by_xpath('//a[@class="header__submenu__list__link"]')
show1.click()

# %%
Song_Names=driver.find_elements_by_xpath('//span[@class="chart-element__information__song text--truncate color--primary"]')   
name=[]
for i in Song_Names:
    name.append(i.text)
    
Artist_Names=driver.find_elements_by_xpath('//span[@class="chart-element__information__artist text--truncate color--secondary"]')   
names=[]
for i in Artist_Names:
    names.append(i.text)
    
Last_Week_Rank=driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--last"]')  
rank=[]
for i in Last_Week_Rank:
    rank.append(i.text)

Peak_Rank=driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--peak"]')  
peak=[]
for i in Last_Week_Rank:
    peak.append(i.text)
    
Weeks_on_Board=driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--week"]')  
week=[]
for i in Weeks_on_Board:
    week.append(i.text)

# %%
Songs=pd.DataFrame()
Songs['Song_Names']=name
Songs['Artist_Names']=names
Songs['Last_Week_Rank']=rank
Songs['Peak_Rank']=peak
Songs['Weeks_on_Board']=week
Songs
# Out:
#        Song_Names                              Artist_Names Last_Week_Rank  \
# 0          Butter                                       BTS              1
# 1        Good 4 U                            Olivia Rodrigo              2
# 2    Kiss Me More                    Doja Cat Featuring SZA              4
# 3      Levitating                 Dua Lipa Featuring DaBaby              3
# 4      Bad Habits                                Ed Sheeran              -
# ..            ...                                       ...            ...
# 95    Twerkulator                                City Girls             96
# 96      Tombstone                                  Rod Wave             83
# 97  Miss The Rage              Trippie Redd & Playboi Carti             82
# 98          Rise!  Tyler, The Creator Featuring Daisy World              -
# 99        Working                       Tate McRae X Khalid             94
#
#    Peak_Rank Weeks_on_Board
# 0          1              6
# ...

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location

# %%
url="https://www.naukri.com/data-science-recruiters"
driver.get(url)

# %%
search_button=driver.find_elements_by_xpath('//button[@class="fl qsbSrch blueBtn"]')

# %%
Name=driver.find_elements_by_xpath('//span[@class="fl ellipsis"]')
name=[]
for i in Name:
    name.append(i.text) 
Designation=driver.find_elements_by_xpath('//span[@class="ellipsis clr"]')
d=[]
for i in Designation:
    d.append(i.text)
Company=driver.find_elements_by_xpath('//a[@class="ellipsis"]')
c=[]
for i in Company:
    c.append(i.text)
Skills_they_hire_for=driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]')
skills=[]
for i in Skills_they_hire_for:
    skills.append(i.text)
Location=driver.find_elements_by_xpath('//small[@class="ellipsis"]')
loc=[]
for i in Location:
    if i.text is None:
        loc.append('--')
    else:
        loc.append(i.text)

# %%
Naukri=pd.DataFrame()
Naukri['Name']=name[0:48]
Naukri['Designation']=d[0:48]
Naukri['Company']=c[1::2][0:48]
Naukri['Skills_they_hire_for']=skills[0:48]
Naukri['Location']=loc[0:48]
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                                    Ruchi Dhote
# 14                             Mahesh Babu Channa
# 15                                   Kapil Devang
# 16                                  Manisha Yadav
# 17                                    Riya Rajesh
# ...

# %%
Name=driver.find_elements_by_xpath('//span[@class="fl ellipsis"]')
name=[]
for i in Name:
    name.append(i.text) 
Designation=driver.find_elements_by_xpath('//span[@class="ellipsis clr"]')
d=[]
for i in Designation:
    d.append(i.text)
Company=driver.find_elements_by_xpath('//a[@class="ellipsis"]')
c=[]
for i in Company:
    c.append(i.text)
Skills_they_hire_for=driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]')
skills=[]
for i in Skills_they_hire_for:
    skills.append(i.text)
Location=driver.find_elements_by_xpath('//small[@class="ellipsis"]')
loc=[]
for i in Location:
    if i.text is None:
        loc.append('--')
    else:
        loc.append(i.text)

# %%
Naukri2=pd.DataFrame()
Naukri2['Name']=name[0:47]
Naukri2['Designation']=d[0:47]
Naukri2['Company']=c[1::2][0:47]
Naukri2['Skills_they_hire_for']=skills[0:47]
Naukri2['Location']=loc[0:47]
Naukri2
# Out:
#                          Name                              Designation  \
# 0                Sunny Sharma                   Managing Director - HR
# 1                  Shailaja.N                        Company Recruiter
# 2                  Sagar Lama                       Company HR Manager
# 3         vidya bhushan singh                                   jaipur
# 4        Dr. S. Prasanna Devi                       Professor and Head
# 5                       Rajni                Team Leader HR Operations
# 6                    Preeti M                        Talent Aquesition
# 7                  Daniel Vaz  Senior Consultant Trading Technology...
# 8            Senior Recruiter                         Senior Recruiter
# 9                   Sam Patel                    Recruitment Executive
# 10              Vivek Kapadia                                 Director
# 11                 Rahul Jain                  Recruitment Consultancy
# ...

# %%
Name=driver.find_elements_by_xpath('//span[@class="fl ellipsis"]')
name=[]
for i in Name:
    name.append(i.text) 
Designation=driver.find_elements_by_xpath('//span[@class="ellipsis clr"]')
d=[]
for i in Designation:
    d.append(i.text)
Company=driver.find_elements_by_xpath('//a[@class="ellipsis"]')
c=[]
for i in Company:
    c.append(i.text)
Skills_they_hire_for=driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]')
skills=[]
for i in Skills_they_hire_for:
    skills.append(i.text)
Location=driver.find_elements_by_xpath('//small[@class="ellipsis"]')
loc=[]
for i in Location:
    if i.text is None:
        loc.append('--')
    else:
        loc.append(i.text)

# %%
Naukri3=pd.DataFrame()
Naukri3['Name']=name[0:50]
Naukri3['Designation']=d[0:50]
Naukri3['Company']=c[1::2][0:50]
Naukri3['Skills_they_hire_for']=skills[0:50]
Naukri3['Location']=loc[0:50]
Naukri3
# Out:
#                          Name                               Designation  \
# 0                Mukesh Kumar                         Company Recruiter
# 1               Gautam Munshi                         Company Recruiter
# 2              Chetan Agarwal                                Co Founder
# 3         Nisanth Vidyadharan                         Company Recruiter
# 4                Sai Kartheek                          Senior Recruiter
# 5             Vasundhara Kaul                         Company Recruiter
# 6           Animesh Choudhuri                          Head Recruitment
# 7                Sekhar Reddy                         Company Recruiter
# 8        Mounica Pulipalupula                            Hiring Manager
# 9           Shaleena Panicker                   Human Resources Manager
# 10                  Swetha.VK             Executive _Talent Acquisition
# 11               Jamil Akhtar                         Company Recruiter
# ...

# %%
Name=driver.find_elements_by_xpath('//span[@class="fl ellipsis"]')
name=[]
for i in Name:
    name.append(i.text) 
Designation=driver.find_elements_by_xpath('//span[@class="ellipsis clr"]')
d=[]
for i in Designation:
    d.append(i.text)
Company=driver.find_elements_by_xpath('//a[@class="ellipsis"]')
c=[]
for i in Company:
    c.append(i.text)
Skills_they_hire_for=driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]')
skills=[]
for i in Skills_they_hire_for:
    skills.append(i.text)
Location=driver.find_elements_by_xpath('//small[@class="ellipsis"]')
loc=[]
for i in Location:
    if i.text is None:
        loc.append('--')
    else:
        loc.append(i.text)

# %%
Naukri4=pd.DataFrame()
Naukri4['Name']=name[0:49]
Naukri4['Designation']=d[0:49]
Naukri4['Company']=c[1::2][0:49]
Naukri4['Skills_they_hire_for']=skills[0:49]
Naukri4['Location']=loc[0:49]
Naukri4
# Out:
#                       Name                            Designation  \
# 0    Surreesha Jagarlamudi                Chief Executive Officer
# 1           Elizabeth Mark                        Human Resources
# 2                    Msima           Senior Recruitment Executive
# 3          RAHUL CHOUDHARI                                    CEO
# 4            Ranjith Badri                  Senior HR Recruitment
# 5              Charu Sethi   Assistant Manager Talent Acquisition
# 6          TSD Corporation                                Manager
# 7                   Rajeev                                Founder
# 8               HS Sandesh     Talent Evangelist www staffiohr co
# 9          Pallavi Kashyap                                Manager
# 10        Akhila Agnihotri      Quantitative Trade Desk Team Lead
# 11           Wayne Spencer                      Company Executive
# 12            Balaram Sahu             Sr Manager Human Resources
# ...

# %%
df=pd.concat([Naukri,Naukri2,Naukri3,Naukri4],ignore_index=True)
df
# Out:
#                    Name              Designation  \
# 0            HR Manager               HR Manager
# 1     Company Recruiter        Company Recruiter
# 2            Company HR               Company HR
# 3     Company Recruiter        Company Recruiter
# 4           Founder CEO              Founder CEO
# ..                  ...                      ...
# 189               Reshu               HR Manager
# 190          Akanksha B        Company Recruiter
# 191                Arya  Human Resources Manager
# 192       Bhuvana Reddy               HR Manager
# 193  Aadith T Prabhakar                  Head HR
#
#                                        Company  \
# 0                         Data Science Network
# 1                Shore Infotech India Pvt. Ltd
# 2                     MARSIAN Technologies LLP
# 3        Enerlytics Software Solutions Pvt Ltd
# 4                              LibraryXProject
# ..                                         ...
# ...

# %% [markdown]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
url="https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/"
driver.get(url)

# %%
name=[]
try:
    Book_Names=driver.find_elements_by_xpath("//table[@class='in-article sortable'][1]/tbody/tr/td[2]")  
    for i in Book_Names:
        name.append(i.text)
except NoSuchElementException:  
        name.append('No details available')
except NoSuchElementException:   
        name.append('No details available')

names=[]
try:
    Author_Names=driver.find_elements_by_xpath("//table[@class='in-article sortable'][1]/tbody/tr/td[3]")  
    for i in Author_Names:
        names.append(i.text)
except NoSuchElementException:  
        names.append('No details available')
except NoSuchElementException:   
        names.append('No details available')        
        
volumes=[]
try:
    Volumes_Sold=driver.find_elements_by_xpath("//table[@class='in-article sortable'][1]/tbody/tr/td[4]")  
    for i in Volumes_Sold:
        volumes.append(i.text)
except NoSuchElementException:  
        volumes.append('No details available')
except NoSuchElementException:   
        volumes.append('No details available')        
        
publisher=[]
try:
    Publisher=driver.find_elements_by_xpath("//table[@class='in-article sortable'][1]/tbody/tr/td[5]")  
    for i in Publisher:
        publisher.append(i.text)
except NoSuchElementException:  
        publisher.append('No details available')
except NoSuchElementException:   
        publisher.append('No details available') 
        
genre=[]
try:
    Genre=driver.find_elements_by_xpath("//table[@class='in-article sortable'][1]/tbody/tr/td[6]")  
    for i in Genre:
        genre.append(i.text)
except NoSuchElementException:  
        genre.append('No details available')
except NoSuchElementException:   
        genre.append('No details available')

# %%
Novels=pd.DataFrame()
Novels['Book_Names']=name
Novels['Author_Names']=names
Novels['Volumes_Sold']=volumes
Novels['Publisher']=publisher
Novels['Genre']=genre
Novels
# Out:
#                                            Book_Names      Author_Names  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_Sold        Publisher                        Genre
# ...

# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com.
#  Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
url="https://www.imdb.com/list/ls095964455/"
driver.get(url)

# %%
Name=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
name=[]
for i in Name:
    name.append(i.text)

Year_span=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")  
year=[]
for i in Year_span:
    year.append(i.text)

Genre=driver.find_elements_by_xpath("//span[@class='genre']")  
genre=[]
for i in Genre:
    genre.append(i.text)

Run_time=driver.find_elements_by_xpath("//span[@class='runtime']")  
time=[]
for i in Run_time:
    time.append(i.text)
    
Ratings=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']")  
rating=[]
for i in Ratings:
    rating.append(i.text)
 
Votes=driver.find_elements_by_xpath("//p[@class='text-muted text-small']")  
votes=[]
for i in Votes:
    votes.append(i.text.replace('Votes:',' '))

# %%
IMDB=pd.DataFrame()
IMDB['Name']=name
IMDB['Year_span']=year
IMDB['Genre']=genre
IMDB['Run_Time']=time
IMDB['Ratings']=rating
IMDB['Votes']=votes[2::3]
IMDB
# Out:
#                               Name    Year_span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run_Time Ratings        Votes
# 0    57 min     9.3    1,832,620
# ...

# %% [markdown]
# 10.Details of Datasets from UCI machine learning repositories.
#  Url = https://archive.ics.uci.edu/
#  You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year

# %%
url='https://archive.ics.uci.edu/'
driver.get(url)

# %%
show=driver.find_element_by_xpath("//a[@href='datasets.php']")
show.click()

# %%
name=[]
try:
    Dataset_Names=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
    for i in Dataset_Names:
        name.append(i.text)
except NoSuchElementException:
    name.append('No details available')
    
data=[]
try:
    Datatype=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for i in Datatype:
        data.append(i.text)
except NoSuchElementException:
    data.append('No details available')
    
task=[]
try:
    Task=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    for i in Task:
        task.append(i.text)
except NoSuchElementException:
    task.append('No details available')
    
att=[]
try:
    Attribute_type=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    for i in Attribute_type:
        att.append(i.text)
except NoSuchElementException:
    att.append('No details available')
    
instances=[]
try:
    Number_of_instances=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    for i in Number_of_instances:
        instances.append(i.text)
except NoSuchElementException:
    instances.append('No details available')
    
attribute=[]
try:
    Number_of_attributes=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    for i in Number_of_attributes:
        attribute.append(i.text)
except NoSuchElementException:
    attribute.append('No details available')
    
year=[]
try:
    Year=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
    for i in Year:
        year.append(i.text)
except NoSuchElementException:
    year.append('No details available')

# %%
Dataset=pd.DataFrame()
Dataset['Dataset_Names']=name
Dataset['Datatype']=data[1:]
Dataset['Task']=task[1:]
Dataset['Attribute_type']=att[1:]
Dataset['Number_of_instances']=instances[1:]
Dataset['Number_of_attributes']=attribute[1:]
Dataset['Year']=year[1:]
Dataset
# Out:
#                         Dataset_Names       Datatype                  Task  \
# 0                             Abalone  Multivariate        Classification
# 1                               Adult  Multivariate        Classification
# 2                           Annealing  Multivariate        Classification
# 3        Anonymous Microsoft Web Data                 Recommender-Systems
# 4                          Arrhythmia  Multivariate        Classification
# ..                                ...            ...                   ...
# 583  in-vehicle coupon recommendation  Multivariate        Classification
# 584               Gait Classification  Multivariate        Classification
# 585         Wikipedia Math Essentials   Time-Series            Regression
# 586         Wikipedia Math Essentials   Time-Series            Regression
# 587      Synchronous Machine Data Set  Multivariate            Regression
#
#                   Attribute_type Number_of_instances Number_of_attributes  \
# ...
